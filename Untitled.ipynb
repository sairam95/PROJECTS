# %%
import pandas as pd

# %%
train = pd.read_csv('train_2017.csv')

# %%
train.head()
# Out:
#    parcelid  logerror transactiondate
# 0  14297519  0.025595      2017-01-01
# 1  17052889  0.055619      2017-01-01
# 2  14186244  0.005383      2017-01-01
# 3  12177905 -0.103410      2017-01-01
# 4  10887214  0.006940      2017-01-01

# %%
prop = pd.read_csv('properties_2016.csv')
# Out:
# F:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
prop.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
merge_df = prop.merge(train, how ='inner')

# %%
len(merge_df.columns)
# Out:
# 60

# %%
merge_df.dropna(thresh=0.40*len(merge_df), axis=1,inplace = True)

# %%
merge_df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17054981          5.0         4.0                    NaN
# 1  17055743          2.0         3.0                    NaN
# 2  17068109          1.5         3.0                    NaN
# 3  17073952          2.0         2.0                    NaN
# 4  17078502          1.0         2.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                5.0                        3760.0                3760.0
# 1                2.0                        1444.0                1444.0
# 2                1.5                        1698.0                1698.0
# 3                2.0                         986.0                 986.0
# 4                1.0                        1170.0                1170.0
#
#      fips  fullbathcnt  heatingorsystemtypeid       ...         unitcnt  \
# 0  6111.0          5.0                    NaN       ...             NaN
# ...

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77613 entries, 0 to 77612
# Data columns (total 31 columns):
# parcelid                        77613 non-null int64
# bathroomcnt                     77489 non-null float64
# bedroomcnt                      77489 non-null float64
# buildingqualitytypeid           49773 non-null float64
# calculatedbathnbr               76754 non-null float64
# calculatedfinishedsquarefeet    77204 non-null float64
# finishedsquarefeet12            73743 non-null float64
# fips                            77489 non-null float64
# fullbathcnt                     76754 non-null float64
# heatingorsystemtypeid           48628 non-null float64
# latitude                        77489 non-null float64
# longitude                       77489 non-null float64
# lotsizesquarefeet               69254 non-null float64
# propertycountylandusecode       77489 non-null object
# propertylandusetypeid           77489 non-null float64
# ...

# %%
merge_df.head(100)
# Out:
#     parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0   17054981          5.0         4.0                    NaN
# 1   17055743          2.0         3.0                    NaN
# 2   17068109          1.5         3.0                    NaN
# 3   17073952          2.0         2.0                    NaN
# 4   17078502          1.0         2.0                    NaN
# 5   17079209          2.0         3.0                    NaN
# 6   17085396          0.0         0.0                    NaN
# 7   17086439          2.0         3.0                    NaN
# 8   17088994          1.0         2.0                    NaN
# 9   17091430          2.5         5.0                    NaN
# 10  17126991          2.0         3.0                    NaN
# 11  17144430          3.0         4.0                    NaN
# 12  17157638          2.0         3.0                    NaN
# 13  17162450          2.0         4.0                    NaN
# ...

# %%
df = merge_df.dropna(axis=0, how ='any')

# %%
len(df.columns)
# Out:
# 31

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
prop.info()

# %%
pd.plot(x = 'basementsqft', y = 'finishedfloor1squarefeet')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sns.

# %%
sns.boxplot(y = prop['finishedsquarefeet12'])
